# %%
import pandas as pd
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt

# %%
dfeth = pd.read_parquet('Data_SOL_Daily.parquet')

# %%
dfeth
# Out:
#                     date      volume        vol     RSI_14    EMA_100  \
# 13   2020-08-24 02:00:00  1316681.19   0.911249  51.290959   3.294880
# 14   2020-08-25 02:00:00  1150403.92   0.878199  49.807714   3.294583
# 15   2020-08-26 02:00:00  2290712.76   0.920187  47.139098   3.300168
# 16   2020-08-27 02:00:00  2414300.08   0.816765  45.846541   3.303437
# 17   2020-08-28 02:00:00  2584550.56   1.010381  59.394732   3.317918
# ..                   ...         ...        ...        ...        ...
# 897  2023-01-25 01:00:00  8395410.25   9.390709  67.135696  22.453982
# 898  2023-01-26 01:00:00  5491087.51   6.254965  59.454897  22.518805
# 899  2023-01-27 01:00:00  4867192.15   6.640074  59.174830  22.657220
# 900  2023-01-28 01:00:00  3623090.01  12.871898  70.055188  22.941719
# 901  2023-01-29 01:00:00  7861815.83  12.941448  55.156824  23.039405
#
#         SMA_50        ADX       open       high        low      close
# ...
